# %%
# Import useful libraries and classes.
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
#html upload
my_url=  "https://www.flipkart.com/search?q=samsung+mobiles&amp;sid=tyy%2C4io&amp;as=on&amp;as-show=on&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;as-pos=1&amp;as-type=RECENT&amp;suggestionId=samsung+mobiles%7CMobiles&amp;requestId=18944876-a6ef-44c0-ac67-d31d7b11a548&amp;as-backfill=on"
uClient= uReq(my_url)
page_html= uClient.read()
uClient.close()

# %%
uClient

# %%
my_url
# Out:
# 'https://www.flipkart.com/search?q=samsung+mobiles&amp;sid=tyy%2C4io&amp;as=on&amp;as-show=on&amp;otracker=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;otracker1=AS_QueryStore_OrganicAutoSuggest_1_5_na_na_na&amp;as-pos=1&amp;as-type=RECENT&amp;suggestionId=samsung+mobiles%7CMobiles&amp;requestId=18944876-a6ef-44c0-ac67-d31d7b11a548&amp;as-backfill=on'

# %%
page_html
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.6e7580.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
page_soup= soup(page_html)
page_soup
# Out:
# <!DOCTYPE html>
# ...

# %%
containers= page_soup.findAll("div", {"class": "_1YokD2"})

# %%
containers
# Out:
# [<div class="_1YokD2 _2GoDe3"><div class="_1YokD2 _3Mn1Gg col-2-12" style="flex:0 0 280px;max-width:280px;padding:0px 10px 0px 0px"><div class="_1YokD2 _3Mn1Gg col-12-12"><div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung+mobiles&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2
# ...

# %%
containers= page_soup.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
containers
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung+mobiles&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?
# ...

# %%
print(len(containers))
# Out:
# 30

# %%
containers= page_soup.findAll("div", {"class": "_1AtVbE col-12-12"})

# %%
containers
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=samsung+mobiles&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?
# ...

# %%
print(len(containers))
# Out:
# 30

# %%
containers= page_soup.findAll("div", {"class": "_13oc-S"})

# %%
print(len(containers))
# Out:
# 24

# %%
import re
filename= "flipkart.csv"
f= open(filename, "w",encoding="UTF-8")

headers= "Mobile_Name,Price,Ratings,Technical_Specifications\n"
f.write(headers)

for container in containers:
    name= container.findAll('div',{"class":"_4rR01T"})
    Name= name[0].text
    Name = re.sub(r"[\(\)]",'',Name)
    Name=Name.replace(",","")
    price= container.findAll("div", {"class": "_30jeq3 _1_WHN1"})
    Price=price[0].text
    Price=Price.replace(",","")
    Price = re.sub('[^A-Za-z0-9]+', '', Price)
    rating=container.findAll("div", {"class": "_3LWZlK"})
    Ratings=rating[0].text
    specification =container.findAll("ul", {"class": "_1xgFaf"})
    Specification=specification[0].text

    f.write(Name + ","+ Price + "," + Ratings + "," + Specification+"\n")


f.close()

# %%
import pandas as pd

# %%
samsung = pd.read_csv("flipkart.csv", encoding="latin-1")
display(samsung)
# Out:
#                                      Mobile_Name  Price  Ratings  \
# 0           SAMSUNG Galaxy F22 Denim Black 64 GB  11999      4.3
# 1           SAMSUNG Galaxy F22 Denim Blue 128 GB  13999      4.3
# 2            SAMSUNG Galaxy F22 Denim Blue 64 GB  11999      4.3
# 3          SAMSUNG Galaxy F22 Denim Black 128 GB  13999      4.3
# 4      SAMSUNG Galaxy F23 5G Copper Blush 128 GB  16999      4.1
# 5         SAMSUNG Galaxy F23 5G Aqua Blue 128 GB  16999      4.1
# 6   SAMSUNG Galaxy M33 5G Deep Ocean Blue 128 GB  16822      4.0
# 7                           SAMSUNG GURU MUSIC 2   1994      4.2
# 8      SAMSUNG Galaxy F23 5G Forest Green 128 GB  16999      4.1
# 9                  SAMSUNG Galaxy M12 Blue 64 GB  10285      4.2
# 10                          SAMSUNG Guru Music 2   1994      4.1
# 11   SAMSUNG Galaxy M33 5G Mystique Green 128 GB  16890      4.0
# 12                          SAMSUNG Guru Music 2   1994      4.3
# ...

# %%
#Task 2

# %%
#html upload
my_url=  "https://www.amazon.in/s?k=samsung&rh=n%3A1389401031&ref=nb_sb_noss"
uClient= uReq(my_url)
page_html= uClient.read()
uClient.close()

# %%
uClient

# %%
page_html
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41wZkyTaWoL.css,31Y8m1dzTdL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21N4kUH7pxL.css,01oDR3IULNL.css,41CYNGpGlrL.css,01XPHJk60-L.css,114y0SIP+yL.css,21aPhFy+riL
# ...

# %%
page_soup= soup(page_html)
page_soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
containers= page_soup.findAll("div", {"class": "sg-col-inner"})

# %%
containers= page_soup.findAll('div', {"class":"sg-col sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 s-list-col-right"})
containers
# Out:
# [<div class="sg-col sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 s-list-col-right"><div class="sg-col-inner"><div class="a-section a-spacing-small a-spacing-top-small"><div class="a-section a-spacing-none s-padding-right-small s-title-instructions-style"><h2 class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"><a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/Samsung-Galaxy-M12-Storage-Processor/dp/B08XGDN3TZ" target="_blank"><span class="a-size-medium a-color-base a-text-normal">Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate</span> </a> </h2></div><div class="a-section a-spacing-none a-spacing-top-micro"><div class="a-row a-size-small"><span aria-label="4.1 out of 5 stars"><span class="a-declarative" data-a-popover='{"closeButton":false,"closeButtonLabel":"","position":"triggerBottom","popoverLabel":"","url":"/review/widgets/average-customer-review/pop
# ...

# %%
containers
# Out:
# [<div class="sg-col sg-col-4-of-12 sg-col-8-of-16 sg-col-12-of-20 s-list-col-right"><div class="sg-col-inner"><div class="a-section a-spacing-small a-spacing-top-small"><div class="a-section a-spacing-none s-padding-right-small s-title-instructions-style"><h2 class="a-size-mini a-spacing-none a-color-base s-line-clamp-2"><a class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal" href="/Samsung-Galaxy-M12-Storage-Processor/dp/B08XGDN3TZ" target="_blank"><span class="a-size-medium a-color-base a-text-normal">Samsung Galaxy M12 (Blue,4GB RAM, 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate</span> </a> </h2></div><div class="a-section a-spacing-none a-spacing-top-micro"><div class="a-row a-size-small"><span aria-label="4.1 out of 5 stars"><span class="a-declarative" data-a-popover='{"closeButton":false,"closeButtonLabel":"","position":"triggerBottom","popoverLabel":"","url":"/review/widgets/average-customer-review/pop
# ...

# %%
print(len(containers))
# Out:
# 24

# %%
import re
filename= "amz_sam.csv"
f= open(filename, "w",encoding="UTF-8")

headers= "Mobile_Name,Price,Ratings,Links,Discounts\n"
f.write(headers)

for phone in containers:
    name= phone.findAll("span",{"class":"a-size-medium a-color-base a-text-normal"})
    Name= name[0].text
    Name=Name.replace(",","")
    link=phone.findAll("a")
    Link=link[0].attrs['href']
    price= phone.findAll("span", {"class": "a-offscreen"})
    Price=price[0].text
    Price = re.sub('[^A-Za-z0-9]+', '', Price)
    rating=phone.findAll("span", {"class": "a-icon-alt"})
    Ratings=rating[0].text
    discount =phone.findAll("span", {"class": None})
    Discount=discount[4].text
    print(Name + ","+ Price + "," + Ratings + ","+Link+"," + Discount+"\n")
    f.write(Name + ","+ Price + "," + Ratings + ","+Link+"," + Discount+"\n")
f.close()
# Out:
# Samsung Galaxy M12 (Blue4GB RAM 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate,10499,4.1 out of 5 stars,/Samsung-Galaxy-M12-Storage-Processor/dp/B08XGDN3TZ,(19% off)
#
# Samsung Galaxy M12 (Black4GB RAM 64GB Storage) 6000 mAh with 8nm Processor | True 48 MP Quad Camera | 90Hz Refresh Rate,10499,4.1 out of 5 stars,/Samsung-Galaxy-M12-Storage-Processor/dp/B08XJCMGL7,(19% off)
#
# Samsung Galaxy M32 (Light Blue 6GB RAM 128GB | FHD+ sAMOLED 90Hz Display | 6000mAh Battery | 64MP Quad Camera,13999,4.1 out of 5 stars,/Samsung-Galaxy-Storage-Months-Replacement/dp/B096VDR283,(26% off)
#
# Samsung Galaxy M32 (Black 4GB RAM 64GB | FHD+ sAMOLED 90Hz Display | 6000mAh Battery | 64MP Quad Camera,11999,4.1 out of 5 stars,/Samsung-Galaxy-Storage-Months-Replacement/dp/B096VDG9QV,(29% off)
#
# ...

# %%
import pandas as pd
amz= pd.read_csv("amz_sam.csv", encoding='latin-1')
amz
# Out:
#                                           Mobile_Name  Price  \
# 0   Samsung Galaxy M12 (Blue4GB RAM 64GB Storage) ...  10499
# 1   Samsung Galaxy M12 (Black4GB RAM 64GB Storage)...  10499
# 2   Samsung Galaxy M32 (Light Blue 6GB RAM 128GB |...  13999
# 3   Samsung Galaxy M32 (Black 4GB RAM 64GB | FHD+ ...  11999
# 4   Samsung Galaxy S20 FE 5G (Cloud Navy 8GB RAM 1...  36990
# 5   Samsung Galaxy M32 5G (Sky Blue 8GB RAM 128GB ...  22999
# 6   Samsung Galaxy A13 Blue 4GB RAM 64GB Storage w...  13999
# 7   Samsung Galaxy M33 5G (Deep Ocean Blue 8GB 128...  19499
# 8   Samsung Galaxy A23 Blue 6GB RAM 128GB Storage ...  18499
# 9   Samsung Galaxy M12 (White4GB RAM 64GB Storage)...  10499
# 10  Samsung Galaxy M32 (Black 6GB RAM 128GB | FHD+...  13999
# 11  Samsung Galaxy M32 5G (Slate Black 6GB RAM 128...  20999
# 12  Samsung Galaxy M33 5G (Deep Ocean Blue 6GB 128...  17999
# 13  Samsung Galaxy A23 Light Blue 6GB RAM 128GB St...  18280
# ...

# %%
amz['Price']
# Out:
# 0     10499
# 1     10499
# 2     13999
# 3     11999
# 4     36990
# 5     22999
# 6     13999
# 7     19499
# 8     18499
# 9     10499
# 10    13999
# 11    20999
# 12    17999
# 13    18280
# 14     7490
# 15    16499
# 16    12999
# 17     1494
# 18    11999
# 19    15250
# 20      419
# 21    14999
# 22    26499
# 23    36990
# Name: Price, dtype: int64

# %% [markdown]
# Create a CSV file for the Task A &amp; B containing all the possible details.
#
# a. Get the phone details with min and max price of the phone in Amazon &amp; flipkart.
#
# b. Get the price of Samsung Galaxy F12 options available with price comparison in
# Amazon &amp; flipkart.

# %%
amz2=pd.DataFrame(amz[amz.Price == amz.Price.max()])
amz3=pd.DataFrame(amz[amz.Price == amz.Price.min()])
print("Maximum Price in Amazon")
amz2
# Out:
# Maximum Price in Amazon
#                                           Mobile_Name  Price  \
# 4   Samsung Galaxy S20 FE 5G (Cloud Navy 8GB RAM 1...  36990
# 23  Samsung Galaxy S20 FE 5G (Cloud Mint 8GB RAM 1...  36990
#
#                Ratings                                              Links  \
# 4   4.4 out of 5 stars  /Samsung-Galaxy-Cloud-128GB-Storage/dp/B08VB57558
# 23  4.4 out of 5 stars  /Samsung-Galaxy-Cloud-128GB-Storage/dp/B08VB2MRF8
#
#     Discounts
# 4   (51% off)
# 23  (51% off)

# %%
print("Minium Price in Amazon")
amz3
# Out:
# Minium Price in Amazon
#                                           Mobile_Name  Price  \
# 20  Samsung EHS64 EHS64AVFWECINU Wired In Ear Earp...    419
#
#                Ratings                                              Links  \
# 20  4.2 out of 5 stars  /Samsung-Original-EHS64AVFWECINU-Stereo-Headse...
#
#     Discounts
# 20  (16% off)

# %%
flipkart1=pd.DataFrame(samsung[samsung.Price == samsung.Price.max()])
flipkart2=pd.DataFrame(samsung[samsung.Price == samsung.Price.min()])
print("Maximum Price")
flipkart1
# Out:
# Maximum Price
#                                      Mobile_Name  Price  Ratings  \
# 22  SAMSUNG Galaxy A52s 5G Awesome Violet 128 GB  28964      4.2
#
#                              Technical_Specifications
# 22  6 GB RAM | 128 GB ROM | Expandable Upto 1 TB16...

# %%
print("Minimum price")
flipkart2
# Out:
# Minimum price
#           Mobile_Name  Price  Ratings  \
# 17    SAMSUNG GURU GT   1494      4.1
# 20  SAMSUNG GURU 1200   1494      3.9
#
#                              Technical_Specifications
# 17  153 MB RAM | 153 MB ROM3.81 cm (1.5 inch) Disp...
# 20  NA MB ROM3.86 cm (1.52 inch) Display800 mAh Ba...

# %% [markdown]
# b. Get the price of Samsung Galaxy F12 options available with price comparison in
# Amazon &amp; flipkart.

# %%
phone = samsung.loc[(samsung['Mobile_Name'] == 'SAMSUNG Galaxy F12 Celestial Black 64 GB') | (samsung['Mobile_Name'] == 'SAMSUNG Galaxy F12 Sea Green 64 GB')]
phone
# Out:
#                                  Mobile_Name  Price  Ratings  \
# 18        SAMSUNG Galaxy F12 Sea Green 64 GB  11499      4.3
# 19  SAMSUNG Galaxy F12 Celestial Black 64 GB  11499      4.3
#
#                              Technical_Specifications
# 18  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
# 19  4 GB RAM | 64 GB ROM | Expandable Upto 512 GB1...
